# %% [markdown]
# ## [--- Day 1: Secret Entrance ---](https://adventofcode.com/2025/day/1)

# %%
def solve() -> None:
    with open("..\\data\\example.txt") as file:
        instructions = [line.strip() for line in file.readlines()]


solve()
