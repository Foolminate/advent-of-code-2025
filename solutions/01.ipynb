# %% [markdown]
# ## [--- Day 1: Secret Entrance ---](https://adventofcode.com/2025/day/1)

# %%
def solve_a() -> None:
    with open('..\\data\\01a.txt') as file:
        instructions = file.readlines()

    left_right = {'L': -1, 'R': 1}
    dial = 50
    sequence = [dial]
    count = 0
    for instruction in instructions:
        direction, degrees = instruction[0], int(instruction[1:])
        dial += left_right[direction] * degrees
        dial %= 100
        sequence.append(dial)
        count += 1 if dial == 0 else 0
    
    print(f"Number of times dial returned to origin: {count}")


solve_a()
# Out:
# Number of times dial returned to origin: 1086

# %%
def solve_b() -> None:
    pass

solve_b()
